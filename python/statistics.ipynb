# %%
import matplotlib.pyplot as plt
import db_connect

dbconn = db_connect.DB_CONN()

# %%
dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'like'")
rows = dbconn.fetchall()
like_count = int(rows[0]['count_'])

dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'user'")
rows = dbconn.fetchall()
user_count = int(rows[0]['count_'])
    
dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'nolike'")
rows = dbconn.fetchall()
nolike_count = int(rows[0]['count_'])
    
dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'content'")
rows = dbconn.fetchall()
content_count = int(rows[0]['count_'])

dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'hot'")
rows = dbconn.fetchall()
area_count = int(rows[0]['count_'])
    
dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'search'")
rows = dbconn.fetchall()
search_count = int(rows[0]['count_'])
    
dbconn.execute("SELECT count(`id`) AS 'count_' FROM `ex_score` WHERE `type` = 'new'")
rows = dbconn.fetchall()
new_count = int(rows[0]['count_'])
print(like_count,user_count,nolike_count,content_count,area_count,search_count,new_count)
# Out:
# 138 35 72 63 36 45 58

# %%
import numpy as np

types = ['All','Customer',"Don't like",'Content','Area','Search','New']
types_times = [like_count,user_count,nolike_count,content_count,area_count,search_count,new_count]

xs = [i*30  for i,_ in enumerate(types)]
plt.bar(xs,types_times,20)
plt.axis([-15,195,0,140])
plt.ylabel("Times")
plt.title("View")

plt.xticks([i*30 for i, _ in enumerate(types)],types)

plt.show()

# %%
types = ['Customer',"Don't like",'Content','Area','Search','New']
types_times = [user_count,nolike_count,content_count,area_count,search_count,new_count]

xs = [i for i,_ in enumerate(types)]
plt.bar(xs,types_times)

plt.ylabel("Times")
plt.title("View")

plt.xticks([i for i, _ in enumerate(types)],types)

plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'like' ORDER BY `value_`")
rows = dbconn.fetchall()
like_num = []
for x in rows:
    like_num.append(round((x['math_'] * 100),1))
    
print(like_num)
# Out:
# [6.0, 9.0, 24.0, 31.0, 30.0]

# %%
types = ['1','2','3','4','5']

xs = [i for i,_ in enumerate(types)]
plt.bar(xs,like_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("All")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'like'")
rows = dbconn.fetchall()

labels = []
sizes = []
colors = ['yellowgreen','lightskyblue','gold', 'lightcoral','yellow']

for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'user' ORDER BY `value_`")
rows = dbconn.fetchall()
user_num = []
for x in rows:
    user_num.append(round((x['math_'] * 100),1))
    
print(user_num)
# Out:
# [6.0, 38.0, 9.0, 25.0, 22.0]

# %%
plt.bar(xs,user_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("Other Users Like")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'user'")
rows = dbconn.fetchall()

labels = []
sizes = []
for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'nolike' ORDER BY `value_`")
rows = dbconn.fetchall()
nolike_num = []
for x in rows:
    nolike_num.append(round((x['math_'] * 100),1))
    
print(nolike_num)
# Out:
# [10.0, 11.0, 28.0, 32.0, 18.0]

# %%
plt.bar(xs,nolike_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("User No Like")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'nolike'")
rows = dbconn.fetchall()

labels = []
sizes = []
for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'content' ORDER BY `value_`")
rows = dbconn.fetchall()
content_num = []
for x in rows:
    content_num.append(round((x['math_'] * 100),1))
    
print(content_num)
# Out:
# [0.0, 0.0, 25.0, 48.0, 27.0]

# %%
plt.bar(xs,content_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("Likes Content")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'content'")
rows = dbconn.fetchall()

labels = []
sizes = []
for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'hot' ORDER BY `value_`")
rows = dbconn.fetchall()
area_num = []
for x in rows:
    area_num.append(round((x['math_'] * 100),1))
    
print(area_num)
# Out:
# [12.0, 24.0, 15.0, 18.0, 32.0]

# %%
plt.bar(xs,area_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("Area Hot")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'hot'")
rows = dbconn.fetchall()

labels = []
sizes = []
for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'search' ORDER BY `value_`")
rows = dbconn.fetchall()
search_num = []
for x in rows:
    search_num.append(round((x['math_'] * 100),1))
    
print(search_num)
# Out:
# [6.0, 18.0, 20.0, 43.0, 14.0]

# %%
plt.bar(xs,search_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("Search Hot")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'search'")
rows = dbconn.fetchall()

labels = []
sizes = []
for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()

# %%
dbconn.execute("SELECT `math_` FROM `ex_score_analysis` WHERE `type_` = 'new' ORDER BY `value_`")
rows = dbconn.fetchall()
new_num = []
for x in rows:
    new_num.append(round((x['math_'] * 100),1))
    
print(new_num)
# Out:
# [6.0, 11.0, 27.0, 33.0, 23.0]

# %%
plt.bar(xs,new_num)

plt.xlabel("Score")
plt.ylabel("Number")
#plt.title("New")

plt.xticks([i for i, _ in enumerate(types)],types)
plt.show()

# %%
dbconn.execute("SELECT `value_`,`math_` FROM `ex_score_analysis` WHERE `type_` = 'new'")
rows = dbconn.fetchall()

labels = []
sizes = []
for x in rows:  
    labels.append(x['value_'])
    sizes.append(x['math_'])
    
plt.figure(figsize=(6,9)) 
 
explode = (0,0,0,0,0.05) 
patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      autopct = '%3.2f%%', 
                      shadow = False, 
                      startangle =90,
                      pctdistance = 0.6)
plt.axis('equal')
plt.show()
